# %% [markdown]
# <a href="https://colab.research.google.com/github/Asica-kos/Project_2_heavy_discounting/blob/main/Business_questions_heavy_discounting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# orders_cl.csv
url = "https://drive.google.com/file/d/1Tla62vfu__kCqvgypZyVt2S9VuC016yH/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orders_cl = pd.read_csv(path)

# orderlines_cl.csv
url = "https://drive.google.com/file/d/1OhtkQS2fwOYdzfd-qPh7im35iLc-L9TA/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orderlines_cl = pd.read_csv(path)

# products_cl.csv
url = "https://drive.google.com/file/d/1s7Lai4NSlsYjGEPg1QSOUJobNYVsZBOJ/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products_cl = pd.read_csv(path)

# brands_cl.csv
url = "https://drive.google.com/file/d/1XGyabaa4mAkjixMk3XPgx_14OoSse3rs/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
brands = pd.read_csv(path)

# %% [markdown]
# ### saving paths as .copy()

# %%
#display orders

# %%
or_df = orders_cl.copy()

# %%
or_df
# Out:
#         order_id         created_date  total_paid            state
# 0         241319  2017-01-02 13:35:40       44.99        Cancelled
# 1         241423  2017-11-06 13:10:02      136.15        Completed
# 2         242832  2017-12-31 17:40:03       15.76        Completed
# 3         243330  2017-02-16 10:59:38       84.98        Completed
# 4         243784  2017-11-24 13:35:19      157.86        Cancelled
# ...          ...                  ...         ...              ...
# 226899    527397  2018-03-14 13:56:38       42.99      Place Order
# 226900    527398  2018-03-14 13:57:25       42.99  Shopping Basket
# 226901    527399  2018-03-14 13:57:34      141.58  Shopping Basket
# 226902    527400  2018-03-14 13:57:41       19.98  Shopping Basket
# 226903    527401  2018-03-14 13:58:36       18.98      Place Order
#
# [226904 rows x 4 columns]

# %%
#display orderlines

# %%
ol_df = orderlines_cl.copy()

# %%
ol_df
# Out:
#              id  id_order  product_id  product_quantity      sku  unit_price  \
# 0       1119109    299539           0                 1  OTT0133       18.99
# 1       1119110    299540           0                 1  LGE0043      399.00
# 2       1119111    299541           0                 1  PAR0071      474.05
# 3       1119112    299542           0                 1  WDT0315       68.39
# 4       1119113    299543           0                 1  JBL0104       23.74
# ...         ...       ...         ...               ...      ...         ...
# 216245  1650199    527398           0                 1  JBL0122       42.99
# 216246  1650200    527399           0                 1  PAC0653      141.58
# 216247  1650201    527400           0                 2  APP0698        9.99
# 216248  1650202    527388           0                 1  BEZ0204       19.99
# 216249  1650203    527401           0                 1  APP0927       13.99
#
#                        date
# ...

# %%
#display products

# %%
pr_df = products_cl.copy()

# %%
pr_df
# Out:
#           sku                                           name  \
# 0     RAI0007              Silver Rain Design mStand Support
# 1     APP0023              Apple Mac Keyboard Keypad Spanish
# 2     APP0025               Mighty Mouse Apple Mouse for Mac
# 3     APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4     KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...       ...                                            ...
# 9987  BEL0376        Belkin Travel Support Apple Watch Black
# 9988  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 9989  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 9990  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 9991  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                    desc  price  in_stock  \
# 0          Aluminum support compatible with all MacBook  59.99         1
# 1             USB ultrathin keyboard Apple Mac Spanish.  59.00         0
# ...

# %%
#display brands

# %%
brands_df = brands

# %%
brands_df
# Out:
#     short       long
# 0     8MO  8Mobility
# 1     ACM       Acme
# 2     ADN     Adonit
# 3     AII      Aiino
# 4     AKI     Akitio
# ..    ...        ...
# 182   XOO     Xoopar
# 183   XRI     X-Rite
# 184   XTO      Xtorm
# 185   ZAG   ZaggKeys
# 186   ZEP       Zepp
#
# [187 rows x 2 columns]

# %% [markdown]
# ### discovering and clearing the dataset

# %%
#check the info() first

# %%
or_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226904 entries, 0 to 226903
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      226904 non-null  int64
#  1   created_date  226904 non-null  object
#  2   total_paid    226904 non-null  float64
#  3   state         226904 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.9+ MB

# %% [markdown]
# *   change **created_date** into **datetime** datatype

# %%
or_df['created_date'] =  pd.to_datetime(or_df["created_date"])

# %%
or_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226904 entries, 0 to 226903
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      226904 non-null  int64
#  1   created_date  226904 non-null  datetime64[ns]
#  2   total_paid    226904 non-null  float64
#  3   state         226904 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 6.9+ MB

# %%
ol_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216250 entries, 0 to 216249
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                216250 non-null  int64
#  1   id_order          216250 non-null  int64
#  2   product_id        216250 non-null  int64
#  3   product_quantity  216250 non-null  int64
#  4   sku               216250 non-null  object
#  5   unit_price        216250 non-null  float64
#  6   date              216250 non-null  object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 11.5+ MB

# %% [markdown]
# *   change **date** into **datetime** datatype

# %%
ol_df["date"] = pd.to_datetime(ol_df["date"])

# %%
ol_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216250 entries, 0 to 216249
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                216250 non-null  int64
#  1   id_order          216250 non-null  int64
#  2   product_id        216250 non-null  int64
#  3   product_quantity  216250 non-null  int64
#  4   sku               216250 non-null  object
#  5   unit_price        216250 non-null  float64
#  6   date              216250 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(4), object(1)
# memory usage: 11.5+ MB

# %%
pr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9992 entries, 0 to 9991
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sku       9992 non-null   object
#  1   name      9992 non-null   object
#  2   desc      9992 non-null   object
#  3   price     9992 non-null   float64
#  4   in_stock  9992 non-null   int64
#  5   type      9946 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 468.5+ KB

# %%
#merge tables together: orders and orderlines

# %%
or_df
# Out:
#         order_id        created_date  total_paid            state
# 0         241319 2017-01-02 13:35:40       44.99        Cancelled
# 1         241423 2017-11-06 13:10:02      136.15        Completed
# 2         242832 2017-12-31 17:40:03       15.76        Completed
# 3         243330 2017-02-16 10:59:38       84.98        Completed
# 4         243784 2017-11-24 13:35:19      157.86        Cancelled
# ...          ...                 ...         ...              ...
# 226899    527397 2018-03-14 13:56:38       42.99      Place Order
# 226900    527398 2018-03-14 13:57:25       42.99  Shopping Basket
# 226901    527399 2018-03-14 13:57:34      141.58  Shopping Basket
# 226902    527400 2018-03-14 13:57:41       19.98  Shopping Basket
# 226903    527401 2018-03-14 13:58:36       18.98      Place Order
#
# [226904 rows x 4 columns]

# %%
#first have a look at completed orders

# %%
or_df['state'].value_counts()
# Out:
# state
# Shopping Basket    117809
# Completed           46605
# Place Order         40883
# Pending             14374
# Cancelled            7233
# Name: count, dtype: int64

# %%
#let's leave only Completed orders first

# %%
or_df.drop(or_df.loc[~(or_df['state'] == 'Completed')]['state'].index)
# Out:
#         order_id        created_date  total_paid      state
# 1         241423 2017-11-06 13:10:02      136.15  Completed
# 2         242832 2017-12-31 17:40:03       15.76  Completed
# 3         243330 2017-02-16 10:59:38       84.98  Completed
# 5         245275 2017-06-28 11:35:37      149.00  Completed
# 6         245595 2017-01-21 12:52:47      112.97  Completed
# ...          ...                 ...         ...        ...
# 226544    527042 2018-03-14 11:47:50       18.98  Completed
# 226572    527070 2018-03-14 11:50:48       24.97  Completed
# 226576    527074 2018-03-14 11:51:42       24.97  Completed
# 226598    527096 2018-03-14 11:58:40       34.96  Completed
# 226614    527112 2018-03-14 12:03:52       14.98  Completed
#
# [46605 rows x 4 columns]

# %%
or_df.drop(or_df.loc[~(or_df['state'] == 'Completed')]['state'].index)['state'].unique()
# Out:
# array(['Completed'], dtype=object)

# %%
or_df = or_df.drop(or_df.loc[~(or_df['state'] == 'Completed')]['state'].index)

# %%
#merge order table with orderlines now

# %%
or_df.merge(ol_df, how='inner', left_on='order_id', right_on='id_order')
# Out:
#        order_id        created_date  total_paid      state       id  id_order  \
# 0        241423 2017-11-06 13:10:02      136.15  Completed  1398738    241423
# 1        242832 2017-12-31 17:40:03       15.76  Completed  1529178    242832
# 2        243330 2017-02-16 10:59:38       84.98  Completed  1181923    243330
# 3        245275 2017-06-28 11:35:37      149.00  Completed  1276706    245275
# 4        245595 2017-01-21 12:52:47      112.97  Completed  1154394    245595
# ...         ...                 ...         ...        ...      ...       ...
# 56709    527042 2018-03-14 11:47:50       18.98  Completed  1649446    527042
# 56710    527070 2018-03-14 11:50:48       24.97  Completed  1649512    527070
# 56711    527074 2018-03-14 11:51:42       24.97  Completed  1649522    527074
# 56712    527096 2018-03-14 11:58:40       34.96  Completed  1649565    527096
# 56713    527112 2018-03-14 12:03:52       14.98  Completed  1649593    527112
#
# ...

# %%
or_ol = or_df.merge(ol_df, how='inner', left_on='order_id', right_on='id_order')

# %%
#check if the 'order_id' is unique

# %%
or_ol['order_id'].nunique()
# Out:
# 43064

# %%
or_ol['id'].nunique()
# Out:
# 56714

# %%
#drop duplicates from 'order_id'

# %%
or_ol.iloc[:, :4].drop_duplicates(subset='order_id')
# Out:
#        order_id        created_date  total_paid      state
# 0        241423 2017-11-06 13:10:02      136.15  Completed
# 1        242832 2017-12-31 17:40:03       15.76  Completed
# 2        243330 2017-02-16 10:59:38       84.98  Completed
# 3        245275 2017-06-28 11:35:37      149.00  Completed
# 4        245595 2017-01-21 12:52:47      112.97  Completed
# ...         ...                 ...         ...        ...
# 56709    527042 2018-03-14 11:47:50       18.98  Completed
# 56710    527070 2018-03-14 11:50:48       24.97  Completed
# 56711    527074 2018-03-14 11:51:42       24.97  Completed
# 56712    527096 2018-03-14 11:58:40       34.96  Completed
# 56713    527112 2018-03-14 12:03:52       14.98  Completed
#
# [43064 rows x 4 columns]

# %%
#or_df = or_ol.iloc[:, :4].drop_duplicates(subset='order_id').copy()

# %%
ids_to_keep = or_ol['id_order'].unique()
or_df = or_df.loc[or_df['order_id'].isin(ids_to_keep)]
ol_df = ol_df.loc[ol_df['id_order'].isin(ids_to_keep)]

# %%
or_ol
# Out:
#        order_id        created_date  total_paid      state       id  id_order  \
# 0        241423 2017-11-06 13:10:02      136.15  Completed  1398738    241423
# 1        242832 2017-12-31 17:40:03       15.76  Completed  1529178    242832
# 2        243330 2017-02-16 10:59:38       84.98  Completed  1181923    243330
# 3        245275 2017-06-28 11:35:37      149.00  Completed  1276706    245275
# 4        245595 2017-01-21 12:52:47      112.97  Completed  1154394    245595
# ...         ...                 ...         ...        ...      ...       ...
# 56709    527042 2018-03-14 11:47:50       18.98  Completed  1649446    527042
# 56710    527070 2018-03-14 11:50:48       24.97  Completed  1649512    527070
# 56711    527074 2018-03-14 11:51:42       24.97  Completed  1649522    527074
# 56712    527096 2018-03-14 11:58:40       34.96  Completed  1649565    527096
# 56713    527112 2018-03-14 12:03:52       14.98  Completed  1649593    527112
#
# ...

# %%
or_df['order_id'].nunique() == ol_df['id_order'].nunique()
# Out:
# True

# %%
or_ol['order_id'].nunique()
# Out:
# 43064

# %%
or_ol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56714 entries, 0 to 56713
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          56714 non-null  int64
#  1   created_date      56714 non-null  datetime64[ns]
#  2   total_paid        56714 non-null  float64
#  3   state             56714 non-null  object
#  4   id                56714 non-null  int64
#  5   id_order          56714 non-null  int64
#  6   product_id        56714 non-null  int64
#  7   product_quantity  56714 non-null  int64
#  8   sku               56714 non-null  object
#  9   unit_price        56714 non-null  float64
#  10  date              56714 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
#merge with product table

# %%
pr_df
# Out:
#           sku                                           name  \
# 0     RAI0007              Silver Rain Design mStand Support
# 1     APP0023              Apple Mac Keyboard Keypad Spanish
# 2     APP0025               Mighty Mouse Apple Mouse for Mac
# 3     APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4     KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...       ...                                            ...
# 9987  BEL0376        Belkin Travel Support Apple Watch Black
# 9988  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 9989  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 9990  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 9991  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                    desc  price  in_stock  \
# 0          Aluminum support compatible with all MacBook  59.99         1
# 1             USB ultrathin keyboard Apple Mac Spanish.  59.00         0
# ...

# %%
or_df
# Out:
#         order_id        created_date  total_paid      state
# 1         241423 2017-11-06 13:10:02      136.15  Completed
# 2         242832 2017-12-31 17:40:03       15.76  Completed
# 3         243330 2017-02-16 10:59:38       84.98  Completed
# 5         245275 2017-06-28 11:35:37      149.00  Completed
# 6         245595 2017-01-21 12:52:47      112.97  Completed
# ...          ...                 ...         ...        ...
# 226544    527042 2018-03-14 11:47:50       18.98  Completed
# 226572    527070 2018-03-14 11:50:48       24.97  Completed
# 226576    527074 2018-03-14 11:51:42       24.97  Completed
# 226598    527096 2018-03-14 11:58:40       34.96  Completed
# 226614    527112 2018-03-14 12:03:52       14.98  Completed
#
# [43064 rows x 4 columns]

# %%
ol_df.merge(pr_df, how='left', on='sku')
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119134    299556           0                 1  CRU0039-A       60.90
# 4      1119145    299561           0                 1    PEB0015      142.49
# ...        ...       ...         ...               ...        ...         ...
# 56709  1649474    525664           0                 1    TUC0207       16.52
# 56710  1649512    527070           0                 2    APP0698        9.99
# 56711  1649522    527074           0                 2    APP0698        9.99
# 56712  1649565    527096           0                 3    APP0698        9.99
# 56713  1649593    527112           0                 1    APP0698        9.99
#
# ...

# %%
ol_df.merge(pr_df, how='left', on='sku').isna().sum()
# Out:
# id                     0
# id_order               0
# product_id             0
# product_quantity       0
# sku                    0
# unit_price             0
# date                   0
# name                1394
# desc                1394
# price               1394
# in_stock            1394
# type                1407
# dtype: int64

# %%
ol_pr = ol_df.merge(pr_df, how='left', on='sku')

# %%
ol_pr.dropna(subset='name')
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119134    299556           0                 1  CRU0039-A       60.90
# 4      1119145    299561           0                 1    PEB0015      142.49
# ...        ...       ...         ...               ...        ...         ...
# 56709  1649474    525664           0                 1    TUC0207       16.52
# 56710  1649512    527070           0                 2    APP0698        9.99
# 56711  1649522    527074           0                 2    APP0698        9.99
# 56712  1649565    527096           0                 3    APP0698        9.99
# 56713  1649593    527112           0                 1    APP0698        9.99
#
# ...

# %%
ol_pr.dropna(subset='name').isna().sum()
# Out:
# id                   0
# id_order             0
# product_id           0
# product_quantity     0
# sku                  0
# unit_price           0
# date                 0
# name                 0
# desc                 0
# price                0
# in_stock             0
# type                13
# dtype: int64

# %%
ol_ids_to_keep = ol_pr.dropna(subset='name')['id'].unique()

# %%
ol_df = ol_df.loc[ol_df['id'].isin(ol_ids_to_keep)].copy()

# %%
ol_pr = ol_pr.dropna(subset='name')

# %%
ol_pr.isna().sum()
# Out:
# id                   0
# id_order             0
# product_id           0
# product_quantity     0
# sku                  0
# unit_price           0
# date                 0
# name                 0
# desc                 0
# price                0
# in_stock             0
# type                13
# dtype: int64

# %%
#I need to update order table

# %%
or_df = or_df.loc[or_df['order_id'].isin(ol_df['id_order'].unique())].copy()

# %%
or_df['order_id'].nunique() == ol_df['id_order'].nunique()
# Out:
# True

# %% [markdown]
# ### **1. What is the time period that the dataset covers?**

# %%
or_ol
# Out:
#        order_id        created_date  total_paid      state       id  id_order  \
# 0        241423 2017-11-06 13:10:02      136.15  Completed  1398738    241423
# 1        242832 2017-12-31 17:40:03       15.76  Completed  1529178    242832
# 2        243330 2017-02-16 10:59:38       84.98  Completed  1181923    243330
# 3        245275 2017-06-28 11:35:37      149.00  Completed  1276706    245275
# 4        245595 2017-01-21 12:52:47      112.97  Completed  1154394    245595
# ...         ...                 ...         ...        ...      ...       ...
# 56709    527042 2018-03-14 11:47:50       18.98  Completed  1649446    527042
# 56710    527070 2018-03-14 11:50:48       24.97  Completed  1649512    527070
# 56711    527074 2018-03-14 11:51:42       24.97  Completed  1649522    527074
# 56712    527096 2018-03-14 11:58:40       34.96  Completed  1649565    527096
# 56713    527112 2018-03-14 12:03:52       14.98  Completed  1649593    527112
#
# ...

# %%
# quaters

# %%
or_ol.loc[:,"quarter"] = or_ol["created_date"].dt.quarter
or_ol
# Out:
#        order_id        created_date  total_paid      state       id  id_order  \
# 0        241423 2017-11-06 13:10:02      136.15  Completed  1398738    241423
# 1        242832 2017-12-31 17:40:03       15.76  Completed  1529178    242832
# 2        243330 2017-02-16 10:59:38       84.98  Completed  1181923    243330
# 3        245275 2017-06-28 11:35:37      149.00  Completed  1276706    245275
# 4        245595 2017-01-21 12:52:47      112.97  Completed  1154394    245595
# ...         ...                 ...         ...        ...      ...       ...
# 56709    527042 2018-03-14 11:47:50       18.98  Completed  1649446    527042
# 56710    527070 2018-03-14 11:50:48       24.97  Completed  1649512    527070
# 56711    527074 2018-03-14 11:51:42       24.97  Completed  1649522    527074
# 56712    527096 2018-03-14 11:58:40       34.96  Completed  1649565    527096
# 56713    527112 2018-03-14 12:03:52       14.98  Completed  1649593    527112
#
# ...

# %%
or_ol.groupby("quarter")["total_paid"].agg(["min", "max"])
# Out:
#           min      max
# quarter
# 1        0.00  6846.87
# 2        4.99  4493.82
# 3        6.98  5799.80
# 4        6.53  6876.94

# %%
or_ol.groupby("quarter")["total_paid"].sum()
# Out:
# quarter
# 1    4223303.15
# 2    1425980.19
# 3    2210522.75
# 4    4963531.42
# Name: total_paid, dtype: float64

# %%
or_ol.groupby("quarter")['order_id'].count()
# Out:
# quarter
# 1    21355
# 2     6234
# 3     9921
# 4    19204
# Name: order_id, dtype: int64

# %%
or_ol['created_date'].min(), or_ol['created_date'].max()
# Out:
# (Timestamp('2017-01-01 01:51:47'), Timestamp('2018-03-14 12:03:52'))

# %%
or_ol['created_date'].max() - or_ol['created_date'].min()
# Out:
# Timedelta('437 days 10:12:05')

# %% [markdown]
# ### **2. What is the overall revenue for that time?**

# %%
date_filtering_df = or_ol.copy()

# %%
# total number of orders of the whole period of time

# %%
date_filtering_df.loc[date_filtering_df['created_date'].between(or_ol['created_date'].min(), or_ol['created_date'].max())]['order_id'].count()
# Out:
# 56714

# %%
# total revenue of the whole period of time

# %%
date_filtering_df.loc[date_filtering_df['created_date'].between(or_ol['created_date'].min(), or_ol['created_date'].max())]['total_paid'].sum()
# Out:
# 12823337.51

# %%
# total revenue of the year 2017

# %%
date_filtering_df.loc[date_filtering_df["created_date"].dt.year == 2017, :]['total_paid'].sum().round(2)
# Out:
# 10274908.64

# %%
total_revenue_2017 = date_filtering_df.loc[date_filtering_df["created_date"].dt.year == 2017, :]['total_paid'].sum()

# %%
# calculating the % of income each quarter in regard to the year 2017

# %% [markdown]
# ## summary of **quarterly** income of the year 2017

# %%
print(f'The 1st quarter generated {((4223303.15 / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017.')
print(f'The 2nd quarter generated {((1425980.19 / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017.')
print(f'The 3rd quarter generated {((2210522.75 / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017.')
print(f'The 4th quarter generated {((4963531.42 / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017.')
# Out:
# The 1st quarter generated 41.1% of total revenue of the year 2017.
# The 2nd quarter generated 13.88% of total revenue of the year 2017.
# The 3rd quarter generated 21.51% of total revenue of the year 2017.
# The 4th quarter generated 48.31% of total revenue of the year 2017.

# %%
# number of orders in 2017

# %%
date_filtering_df.loc[date_filtering_df['created_date'].dt.year == 2017]['order_id'].count()
# Out:
# 44857

# %%
number_of_orders_total_2017 = date_filtering_df.loc[date_filtering_df['created_date'].dt.year == 2017]['order_id'].count()

# %% [markdown]
# ### **quarterly** summary of number of orders

# %%
print(f'During 1st quarter, the % of number of orders made {((21355 / number_of_orders_total_2017)*100).round(2)}% of total number of orders of the year 2017.')
print(f'During 2nd quarter, the % of number of orders made {((6234 / number_of_orders_total_2017)*100).round(2)}% of total number of orders of the year 2017.')
print(f'During 3rd quarter, the % of number of orders made {((9921 / number_of_orders_total_2017)*100).round(2)}% of total number of orders of the year 2017.')
print(f'During 4th quarter, the % of number of orders made {((19204 / number_of_orders_total_2017)*100).round(2)}% of total number of orders of the year 2017.')
# Out:
# During 1st quarter, the % of number of orders made 47.61% of total number of orders of the year 2017.
# During 2nd quarter, the % of number of orders made 13.9% of total number of orders of the year 2017.
# During 3rd quarter, the % of number of orders made 22.12% of total number of orders of the year 2017.
# During 4th quarter, the % of number of orders made 42.81% of total number of orders of the year 2017.

# %% [markdown]
# ### **3. Are there seasonal patterns in the evolution of sales?**

# %%
# Christmas time - mid Dec and end of Dec

# %%
# number of orders during Christmas sales

# %%
date_filtering_df.loc[date_filtering_df['created_date'].between('2017-12-10', '2018-01-01')]['order_id'].count()
# Out:
# 5450

# %%
number_of_orders_Xmas_sale = date_filtering_df.loc[date_filtering_df['created_date'].between('2017-12-10', '2018-01-01')]['order_id'].count()

# %%
# revenue from the Christmas sales

# %%
date_filtering_df.loc[date_filtering_df['created_date'].between('2017-12-10', '2018-01-01')]['total_paid'].sum()
# Out:
# 1326551.7999999998

# %%
revenue_Xmas_sale = date_filtering_df.loc[date_filtering_df['created_date'].between('2017-12-10', '2018-01-01')]['total_paid'].sum()

# %%
# calculation of % of income from Xmas sales

# %%
# The % of income from Christams sales in regard to the total income of the year 2017

# %%
print(f'The Christmas sales generated {((revenue_Xmas_sale / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017.')
# Out:
# The Christmas sales generated 12.91% of total revenue of the year 2017.

# %%
# % of number of orders of Christmas Sale in regard to total amount orders throughout the year 2017

# %%
print(f'During Christmas sales, the % of number of orders made {((number_of_orders_Xmas_sale / number_of_orders_total_2017)*100).round(2)}% of total number of orders of the year 2017.')
# Out:
# During Christmas sales, the % of number of orders made 12.15% of total number of orders of the year 2017.

# %%
print(f'The Christmas sales generated {((revenue_Xmas_sale / 4963531.42)*100).round(2)}% of total revenue of the 4th quarter of the year 2017.')
# Out:
# The Christmas sales generated 26.73% of total revenue of the 4th quarter of the year 2017.

# %%
# Black Friday sales

# %%
# number of orders during Black Friday

# %%
date_filtering_df.loc[date_filtering_df['created_date'].dt.strftime("%Y-%m-%d") == '2017-11-24']['order_id'].count()
# Out:
# 2003

# %%
number_of_orders_black_friday = date_filtering_df.loc[date_filtering_df['created_date'].dt.strftime("%Y-%m-%d") == '2017-11-24']['order_id'].count()

# %%
# revenue from the Black Friday

# %%
date_filtering_df.loc[date_filtering_df['created_date'].dt.strftime("%Y-%m-%d") == '2017-11-24']['total_paid'].sum()
# Out:
# 652624.1699999999

# %%
black_friday_sale = date_filtering_df.loc[date_filtering_df['created_date'].dt.strftime("%Y-%m-%d") == '2017-11-24']['total_paid'].sum()

# %%
# The % of income from Black Friday in regard to the total income of the year 2017

# %%
print(f'The Black Friday sales generated {((black_friday_sale / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
# Out:
# The Black Friday sales generated 6.35% of total revenue of the year 2017

# %%
# % of number of orders of Black Friday in regard to total amount orders throughout the year 2017

# %%
print(f'During Black Friday sales, the % of number of orders made {((number_of_orders_black_friday / number_of_orders_total_2017)*100).round(2)}% of total number of orders of the year 2017.')
# Out:
# During Black Friday sales, the % of number of orders made 4.47% of total number of orders of the year 2017.

# %%
# The % of income from Black Friday in regard to the total income of the Christmas sales period of the year 2017

# %%
print(f'The Black Friday sales generated {((black_friday_sale / revenue_Xmas_sale)*100).round(2)}% of total revenue of the Christams sale in the year 2017')
# Out:
# The Black Friday sales generated 49.2% of total revenue of the Christams sale in the year 2017

# %%
print(f'The Black Friday sales generated {((black_friday_sale / 4963531.42)*100).round(2)}% of total revenue of the 4th quarter of the year 2017.')
# Out:
# The Black Friday sales generated 13.15% of total revenue of the 4th quarter of the year 2017.

# %%
# Let's check the montly income throughout the year 2017

# %%
# Jan

# %%
date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 1) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()
# Out:
# 1076463.39

# %%
jan = date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 1) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()

# %%
print(f'January generated {(( jan / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
# Out:
# January generated 10.48% of total revenue of the year 2017

# %%
# Feb

# %%
date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 2) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()
# Out:
# 559303.3899999999

# %%
feb = date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 2) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()

# %%
print(f'February generated {(( feb / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
# Out:
# February generated 5.44% of total revenue of the year 2017

# %%
# March

# %%
date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 3) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()
# Out:
# 39107.5

# %%
march = date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 3) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()

# %%
print(f'March generated {((march / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
# Out:
# March generated 0.38% of total revenue of the year 2017

# %%
# Apr

# %%
date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 4) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()
# Out:
# 386674.70999999996

# %%
apr = date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 4) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()

# %%
print(f'April generated {((apr / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
# Out:
# April generated 3.76% of total revenue of the year 2017

# %%
# May

# %%
date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 5) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()
# Out:
# 531927.1100000001

# %%
may = date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 5) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()

# %%
print(f'May generated {((may / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
# Out:
# May generated 5.18% of total revenue of the year 2017

# %%
# Jun

# %%
date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 6) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()
# Out:
# 507378.37

# %%
jun = date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 6) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()

# %%
print(f'June generated {((jun / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
# Out:
# June generated 4.94% of total revenue of the year 2017

# %%
# Jul

# %%
date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 7) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()
# Out:
# 988687.54

# %%
jul = date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 7) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()

# %%
print(f'July generated {((jul / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
# Out:
# July generated 9.62% of total revenue of the year 2017

# %%
# Aug

# %%
date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 8) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()
# Out:
# 589515.6900000001

# %%
aug = date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 8) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()

# %%
print(f'August generated {((aug / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
# Out:
# August generated 5.74% of total revenue of the year 2017

# %%
# Sep

# %%
date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 9) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()
# Out:
# 632319.52

# %%
sep = date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 9) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()

# %%
print(f'September generated {((sep / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
# Out:
# September generated 6.15% of total revenue of the year 2017

# %%
# Oct

# %%
date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 10) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()
# Out:
# 895959.3799999999

# %%
oct = date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 10) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()

# %%
print(f'October generated {((oct / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
# Out:
# October generated 8.72% of total revenue of the year 2017

# %%
# Nov

# %%
date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 11) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()
# Out:
# 2527381.94

# %%
nov = date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 11) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()

# %%
print(f'November generated {((nov / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
# Out:
# November generated 24.6% of total revenue of the year 2017

# %%
# Dec

# %%
date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 12) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()
# Out:
# 1540190.1

# %%
dec = date_filtering_df.loc[(date_filtering_df["created_date"].dt.month == 12) & (date_filtering_df["created_date"].dt.year == 2017), :]['total_paid'].sum()

# %%
print(f'December generated {((dec / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017.')
# Out:
# December generated 14.99% of total revenue of the year 2017.

# %% [markdown]
# ### summary of the **monthly** income throughout the year 2017

# %%
print(f'January generated {(( jan / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
print(f'February generated {(( feb / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
print(f'March generated {((march / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
print(f'April generated {((apr / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
print(f'May generated {((may / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
print(f'June generated {((jun / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
print(f'July generated {((jul / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
print(f'August generated {((aug / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
print(f'September generated {((sep / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
print(f'October generated {((oct / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
print(f'November generated {((nov / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
print(f'December generated {((dec / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017.')
# Out:
# January generated 10.48% of total revenue of the year 2017
# February generated 5.44% of total revenue of the year 2017
# March generated 0.38% of total revenue of the year 2017
# April generated 3.76% of total revenue of the year 2017
# May generated 5.18% of total revenue of the year 2017
# June generated 4.94% of total revenue of the year 2017
# July generated 9.62% of total revenue of the year 2017
# August generated 5.74% of total revenue of the year 2017
# September generated 6.15% of total revenue of the year 2017
# October generated 8.72% of total revenue of the year 2017
# November generated 24.6% of total revenue of the year 2017
# December generated 14.99% of total revenue of the year 2017.

# %%
# % of Christmas sales in regard to December income

# %%
print(f'Christmas sale generated {((revenue_Xmas_sale/ dec)*100).round(2)}% of total revenue of December in the year 2017.')
# Out:
# Christmas sale generated 86.13% of total revenue of December in the year 2017.

# %% [markdown]
# ## summary of the **Christmas sales**

# %%
print(f'During Christmas sales, the % of number of orders made {((number_of_orders_Xmas_sale / number_of_orders_total_2017)*100).round(2)}% of total number of orders of the year 2017.')
print(f'The Christmas sales generated {((revenue_Xmas_sale / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017.')
print(f'The Christmas sales generated {((revenue_Xmas_sale / 4963531.42)*100).round(2)}% of total revenue of the 4th quarter of the year 2017.')
print(f'Christmas sales generated {((revenue_Xmas_sale/ dec)*100).round(2)}% of total revenue of December in the year 2017.')
# Out:
# During Christmas sales, the % of number of orders made 12.15% of total number of orders of the year 2017.
# The Christmas sales generated 12.91% of total revenue of the year 2017.
# The Christmas sales generated 26.73% of total revenue of the 4th quarter of the year 2017.
# Christmas sales generated 86.13% of total revenue of December in the year 2017.

# %%
# % of Black Friday sales in regard to Nov income

# %%
print(f'Black Friday sale generated {((black_friday_sale/ nov)*100).round(2)}% of total revenue of November in the year 2017.')
# Out:
# Black Friday sale generated 25.82% of total revenue of November in the year 2017.

# %% [markdown]
# ### summary of the **Black Friday sales**

# %%
print(f'During Black Friday sales, the % of number of orders made {((number_of_orders_black_friday / number_of_orders_total_2017)*100).round(2)}% of total number of orders of the year 2017.')
print(f'The Black Friday sales generated {((black_friday_sale / total_revenue_2017)*100).round(2)}% of total revenue of the year 2017')
print(f'The Black Friday sales generated {((black_friday_sale / 4963531.42)*100).round(2)}% of total revenue of the 4th quarter of the year 2017.')
print(f'Black Friday sale generated {((black_friday_sale/ nov)*100).round(2)}% of total revenue of November in the year 2017.')
print(f'The Black Friday sales generated {((black_friday_sale / revenue_Xmas_sale)*100).round(2)}% of total revenue of the Christams sale in the year 2017')
# Out:
# During Black Friday sales, the % of number of orders made 4.47% of total number of orders of the year 2017.
# The Black Friday sales generated 6.35% of total revenue of the year 2017
# The Black Friday sales generated 13.15% of total revenue of the 4th quarter of the year 2017.
# Black Friday sale generated 25.82% of total revenue of November in the year 2017.
# The Black Friday sales generated 49.2% of total revenue of the Christams sale in the year 2017

# %% [markdown]
# ### time line for each month of the year 2017

# %%
date_filtering_df
# Out:
#        order_id        created_date  total_paid      state       id  id_order  \
# 0        241423 2017-11-06 13:10:02      136.15  Completed  1398738    241423
# 1        242832 2017-12-31 17:40:03       15.76  Completed  1529178    242832
# 2        243330 2017-02-16 10:59:38       84.98  Completed  1181923    243330
# 3        245275 2017-06-28 11:35:37      149.00  Completed  1276706    245275
# 4        245595 2017-01-21 12:52:47      112.97  Completed  1154394    245595
# ...         ...                 ...         ...        ...      ...       ...
# 56709    527042 2018-03-14 11:47:50       18.98  Completed  1649446    527042
# 56710    527070 2018-03-14 11:50:48       24.97  Completed  1649512    527070
# 56711    527074 2018-03-14 11:51:42       24.97  Completed  1649522    527074
# 56712    527096 2018-03-14 11:58:40       34.96  Completed  1649565    527096
# 56713    527112 2018-03-14 12:03:52       14.98  Completed  1649593    527112
#
# ...

# %%
# time line for the whole year

# %%
or_ol.loc[:,"month"] = or_ol["created_date"].dt.month
or_ol
# Out:
#        order_id        created_date  total_paid      state       id  id_order  \
# 0        241423 2017-11-06 13:10:02      136.15  Completed  1398738    241423
# 1        242832 2017-12-31 17:40:03       15.76  Completed  1529178    242832
# 2        243330 2017-02-16 10:59:38       84.98  Completed  1181923    243330
# 3        245275 2017-06-28 11:35:37      149.00  Completed  1276706    245275
# 4        245595 2017-01-21 12:52:47      112.97  Completed  1154394    245595
# ...         ...                 ...         ...        ...      ...       ...
# 56709    527042 2018-03-14 11:47:50       18.98  Completed  1649446    527042
# 56710    527070 2018-03-14 11:50:48       24.97  Completed  1649512    527070
# 56711    527074 2018-03-14 11:51:42       24.97  Completed  1649522    527074
# 56712    527096 2018-03-14 11:58:40       34.96  Completed  1649565    527096
# 56713    527112 2018-03-14 12:03:52       14.98  Completed  1649593    527112
#
# ...

# %%
or_ol.loc[:,"year"] = or_ol["created_date"].dt.year
or_ol
# Out:
#        order_id        created_date  total_paid      state       id  id_order  \
# 0        241423 2017-11-06 13:10:02      136.15  Completed  1398738    241423
# 1        242832 2017-12-31 17:40:03       15.76  Completed  1529178    242832
# 2        243330 2017-02-16 10:59:38       84.98  Completed  1181923    243330
# 3        245275 2017-06-28 11:35:37      149.00  Completed  1276706    245275
# 4        245595 2017-01-21 12:52:47      112.97  Completed  1154394    245595
# ...         ...                 ...         ...        ...      ...       ...
# 56709    527042 2018-03-14 11:47:50       18.98  Completed  1649446    527042
# 56710    527070 2018-03-14 11:50:48       24.97  Completed  1649512    527070
# 56711    527074 2018-03-14 11:51:42       24.97  Completed  1649522    527074
# 56712    527096 2018-03-14 11:58:40       34.96  Completed  1649565    527096
# 56713    527112 2018-03-14 12:03:52       14.98  Completed  1649593    527112
#
# ...

# %%
or_ol.groupby(['year', 'month'])['total_paid'].sum().reset_index()
# Out:
#     year  month  total_paid
# 0   2017      1  1076463.39
# 1   2017      2   559303.39
# 2   2017      3    39107.50
# 3   2017      4   386674.71
# 4   2017      5   531927.11
# 5   2017      6   507378.37
# 6   2017      7   988687.54
# 7   2017      8   589515.69
# 8   2017      9   632319.52
# 9   2017     10   895959.38
# 10  2017     11  2527381.94
# 11  2017     12  1540190.10
# 12  2018      1  1394971.71
# 13  2018      2   825950.40
# 14  2018      3   327506.76

# %%
monthly_income = or_ol.groupby(['year', 'month'])['total_paid'].sum().reset_index()

# %%
(
 date_filtering_df.loc[date_filtering_df['created_date'].between('2017-01-01', '2018-02-03')]
 .resample('M', on='created_date')
 ['total_paid'].sum()
 .plot(figsize=(14,6)));

# %%
# time line for Jan income - 'post Christmas sales'??

# %%
(
 date_filtering_df.loc[date_filtering_df['created_date'].dt.strftime("%Y-%m") == '2017-01']
 .resample('D', on='created_date')
 ['total_paid'].sum()
 .plot(figsize=(14,6)));

# %%
# time line for Jul income - 'sommer sale'??

# %%
(
 date_filtering_df.loc[date_filtering_df['created_date'].dt.strftime("%Y-%m") == '2017-07']
 .resample('D', on='created_date')
 ['total_paid'].sum()
 .plot(figsize=(14,6))

);

# %%
# time line for Oct income - 'school time sale'??

# %%
(
 date_filtering_df.loc[date_filtering_df['created_date'].dt.strftime("%Y-%m") == '2017-10']
 .resample('D', on='created_date')
 ['total_paid'].sum()
 .plot(figsize=(14,6))

);

# %%
# time line for Nov income - 'pre Christmas sale'??

# %%
(
 date_filtering_df.loc[date_filtering_df['created_date'].dt.strftime("%Y-%m") == '2017-11']
 .resample('D', on='created_date')
 ['total_paid'].sum()
 .plot(figsize=(14,6))

);

# %% [markdown]
# Most of the income comes from the orders placed at the end of the month, pre-Christmas sale, Black Friday??

# %%
# time line for Dec income - 'Christmas sale'

# %%
(
 date_filtering_df.loc[date_filtering_df['created_date'].dt.strftime("%Y-%m") == '2017-12']
 .resample('D', on='created_date')
 ['total_paid'].sum()
 .plot(figsize=(14,6))

);

# %% [markdown]
# ### **4. What are the most sold products?**

# %%
ol_pr
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119134    299556           0                 1  CRU0039-A       60.90
# 4      1119145    299561           0                 1    PEB0015      142.49
# ...        ...       ...         ...               ...        ...         ...
# 56709  1649474    525664           0                 1    TUC0207       16.52
# 56710  1649512    527070           0                 2    APP0698        9.99
# 56711  1649522    527074           0                 2    APP0698        9.99
# 56712  1649565    527096           0                 3    APP0698        9.99
# 56713  1649593    527112           0                 1    APP0698        9.99
#
# ...

# %%
# most sold items

# %%
ol_pr.groupby(['sku', 'name'])[['product_quantity']].sum().sort_values(ascending=False, by='product_quantity').head(20)
# Out:
#                                                               product_quantity
# sku       name
# APP1190   IPhone AppleCare Protection Plan                                 965
# APP0698   Apple Lightning Cable Connector to USB 1m White...               838
# APP1922   AirPods Apple Bluetooth Headset for iPhone iPad...               563
# WDT0183   Red 4TB WD 35 "Mac PC hard drive and NAS                         505
# APP0927   EarPods Apple Headphones with Remote and Mic (OEM)               493
# CRU0051   Crucial MX300 525GB SSD Disk                                     359
# SAM0074   Samsung 850 EVO SSD Disk 500GB                                   356
# NTE0013   AdaptaDrive NewerTech adapter 2.5 "to 3.5" SATA                  292
# APP2446   Apple iPhone 6 32GB Space Gray                                   271
# CRU0050   Crucial MX300 275GB SSD Disk                                     262
# WDT0141   WD Red 3TB 35 "Mac PC hard drive and NAS                         253
# ...

# %%
# assign the table

# %%
most_sold_products_20 = ol_pr.groupby(['sku', 'name'])[['product_quantity']].sum().sort_values(ascending=False, by='product_quantity').head(20)

# %%
# number of sold most popular products

# %%
most_sold_products_20['product_quantity'].sum()
# Out:
# 7223

# %%
or_ol.loc[:, 'short'] = or_ol['sku'].str[:3]

# %%
or_ol
# Out:
#        order_id        created_date  total_paid      state       id  id_order  \
# 0        241423 2017-11-06 13:10:02      136.15  Completed  1398738    241423
# 1        242832 2017-12-31 17:40:03       15.76  Completed  1529178    242832
# 2        243330 2017-02-16 10:59:38       84.98  Completed  1181923    243330
# 3        245275 2017-06-28 11:35:37      149.00  Completed  1276706    245275
# 4        245595 2017-01-21 12:52:47      112.97  Completed  1154394    245595
# ...         ...                 ...         ...        ...      ...       ...
# 56709    527042 2018-03-14 11:47:50       18.98  Completed  1649446    527042
# 56710    527070 2018-03-14 11:50:48       24.97  Completed  1649512    527070
# 56711    527074 2018-03-14 11:51:42       24.97  Completed  1649522    527074
# 56712    527096 2018-03-14 11:58:40       34.96  Completed  1649565    527096
# 56713    527112 2018-03-14 12:03:52       14.98  Completed  1649593    527112
#
# ...

# %% [markdown]
# ### **5. What are the products that generate the most revenue?**

# %%
# products that bring the most income

# %%
or_ol.groupby('sku')[['product_quantity', 'unit_price']].sum().sort_values(ascending=False, by='unit_price').head(20)
# Out:
#          product_quantity  unit_price
# sku
# LGE0044               243   116033.15
# APP2446               271   101083.49
# APP1922               563    85921.92
# APP2477               111    82683.26
# APP1970               228    81356.18
# APP2072                78    74816.30
# APP2485                83    72779.87
# APP2483                69    57012.00
# APP2479                68    52855.41
# APP1966               141    50306.12
# SAM0074               356    49178.89
# APP1190               965    47714.64
# APP2478                59    44917.51
# APP1971                94    43635.42
# APP1978               128    42138.25
# WDT0183               505    42103.91
# AP20264                55    40320.29
# CRU0051               359    40262.24
# APP2501               103    39534.45
# APP2484                42    37430.46

# %%
most_income = or_ol.groupby('sku')[['product_quantity', 'unit_price']].sum().sort_values(ascending=False, by='unit_price').head(20)

# %%
# number of sold most revenue products

# %%
most_income['product_quantity'].sum()
# Out:
# 4521

# %%
most_income.merge(pr_df, left_on='sku', right_on='sku', how='inner')
# Out:
#         sku  product_quantity  unit_price  \
# 0   LGE0044               243   116033.15
# 1   APP2446               271   101083.49
# 2   APP1922               563    85921.92
# 3   APP2477               111    82683.26
# 4   APP1970               228    81356.18
# 5   APP2072                78    74816.30
# 6   APP2485                83    72779.87
# 7   APP2483                69    57012.00
# 8   APP2479                68    52855.41
# 9   APP1966               141    50306.12
# 10  SAM0074               356    49178.89
# 11  APP1190               965    47714.64
# 12  APP2478                59    44917.51
# 13  APP1971                94    43635.42
# 14  APP1978               128    42138.25
# 15  WDT0183               505    42103.91
# 16  AP20264                55    40320.29
# 17  CRU0051               359    40262.24
# 18  APP2501               103    39534.45
# 19  APP2484                42    37430.46
#
#                                                  name  \
# ...

# %%
most_income_products = most_income.merge(pr_df, left_on='sku', right_on='sku', how='inner')

# %% [markdown]
# ### Creating **category**

# %%
# create column = 'category'

# %%
ol_pr['category'] = ''

# %%
ol_pr
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119134    299556           0                 1  CRU0039-A       60.90
# 4      1119145    299561           0                 1    PEB0015      142.49
# ...        ...       ...         ...               ...        ...         ...
# 56709  1649474    525664           0                 1    TUC0207       16.52
# 56710  1649512    527070           0                 2    APP0698        9.99
# 56711  1649522    527074           0                 2    APP0698        9.99
# 56712  1649565    527096           0                 3    APP0698        9.99
# 56713  1649593    527112           0                 1    APP0698        9.99
#
# ...

# %%
# connect name and desc together

# %%
ol_pr[['name','desc']].agg(''.join, axis=1)
# Out:
# 0        OWC In-line Digital Temperature Sensor Kit HDD...
# 1        iOttie Easy View 2 Car Black SupportIPhone car...
# 2        Apple 85W MagSafe 2 charger MacBook Pro screen...
# 3        (Open) Crucial 240GB SSD 7mm BX200SSD hard dri...
# 4        Pebble Smartwatch Time Steel BlackBluetooth Sm...
#                                ...
# 56709    Tucano Elements Second Skin Macbook Sleeve 12 ...
# 56710    Apple Lightning Cable Connector to USB 1m Whit...
# 56711    Apple Lightning Cable Connector to USB 1m Whit...
# 56712    Apple Lightning Cable Connector to USB 1m Whit...
# 56713    Apple Lightning Cable Connector to USB 1m Whit...
# Length: 55320, dtype: object

# %%
ol_pr['combined'] = ol_pr[['name','desc']].agg(''.join, axis=1)

# %%
ol_pr
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119134    299556           0                 1  CRU0039-A       60.90
# 4      1119145    299561           0                 1    PEB0015      142.49
# ...        ...       ...         ...               ...        ...         ...
# 56709  1649474    525664           0                 1    TUC0207       16.52
# 56710  1649512    527070           0                 2    APP0698        9.99
# 56711  1649522    527074           0                 2    APP0698        9.99
# 56712  1649565    527096           0                 3    APP0698        9.99
# 56713  1649593    527112           0                 1    APP0698        9.99
#
# ...

# %%
ol_pr.drop(['product_id', 'name','desc'], axis=1)
# Out:
#             id  id_order  product_quantity        sku  unit_price  \
# 0      1119116    299545                 1    OWC0100       47.49
# 1      1119119    299546                 1    IOT0014       18.99
# 2      1119120    295347                 1    APP0700       72.19
# 3      1119134    299556                 1  CRU0039-A       60.90
# 4      1119145    299561                 1    PEB0015      142.49
# ...        ...       ...               ...        ...         ...
# 56709  1649474    525664                 1    TUC0207       16.52
# 56710  1649512    527070                 2    APP0698        9.99
# 56711  1649522    527074                 2    APP0698        9.99
# 56712  1649565    527096                 3    APP0698        9.99
# 56713  1649593    527112                 1    APP0698        9.99
#
#                      date   price  in_stock      type category  \
# 0     2017-01-01 01:46:16   60.99       1.0  12755395
# ...

# %%
combined_columns = ol_pr.drop(['product_id', 'name','desc'], axis=1)

# %% [markdown]
# ### combined columns of 'name' and 'desc'

# %%
combined_columns
# Out:
#             id  id_order  product_quantity        sku  unit_price  \
# 0      1119116    299545                 1    OWC0100       47.49
# 1      1119119    299546                 1    IOT0014       18.99
# 2      1119120    295347                 1    APP0700       72.19
# 3      1119134    299556                 1  CRU0039-A       60.90
# 4      1119145    299561                 1    PEB0015      142.49
# ...        ...       ...               ...        ...         ...
# 56709  1649474    525664                 1    TUC0207       16.52
# 56710  1649512    527070                 2    APP0698        9.99
# 56711  1649522    527074                 2    APP0698        9.99
# 56712  1649565    527096                 3    APP0698        9.99
# 56713  1649593    527112                 1    APP0698        9.99
#
#                      date   price  in_stock      type category  \
# 0     2017-01-01 01:46:16   60.99       1.0  12755395
# ...

# %%
ol_pr['category'] = 'Uncategorized'

# %%
ol_pr.loc[ol_pr['name'].str.contains('iphone', case=False), 'category'] = 'Smartphone'
ol_pr.loc[ol_pr['name'].str.contains('Wacom|airpods|headset|Apple Lightning Cable|keyboard|charger|monitor|case|gloves|cover|LEDS|cube|Stabilizer|Gadget|CandyShell|Wacom|LED|battery|pencil|mouse|adapter|glass|usb|armband|speaker|airpods|earpods|CandyShell|holder|cable|car|headphones|HDMI|protector|bulb|dock|pointer|Lens|pen|support|Tweezers|waterproof', case=False), 'category'] = 'Accessories'
ol_pr.loc[ol_pr['name'].str.contains('ram|storage|drive|disc|memory|disk|network|card|system|SSD|DVD|Desktop|link|Wikango', case=False), 'category'] = 'Hardware'
ol_pr.loc[ol_pr['name'].str.contains('thermostat|temperature|thermometer|Pluviometer|smart|Wi-Fi Repeater|Intelligent|Smartwatch|watch|wireless|bluetooth|sensor|tech|drone|glucímetros', case=False), 'category'] = 'Smart tech'
ol_pr.loc[ol_pr['name'].str.contains('ipod|player', case=False), 'category'] = 'MP3 player'
ol_pr.loc[ol_pr['name'].str.contains('ipad|tablet', case=False), 'category'] = 'Tablet'
ol_pr.loc[ol_pr['name'].str.contains('MacBook|iMac', case=False), 'category'] = 'PC'
ol_pr.loc[ol_pr['name'].str.contains('service|server|kit|applecare|tool|cleaner|spray|converter|button|router', case=False), 'category'] = 'Service'
ol_pr.loc[ol_pr['name'].str.contains('camera|polaroid|printer|GoPro', case=False), 'category'] = 'Digital'

# %%
ol_pr.loc[ol_pr["sku"] == "WAC0171", "category"] = "Accessories"

# %%
ol_pr.loc[ol_pr["sku"] == "APP1922", "category"] = "Accessories"

# %%
ol_pr['category'].value_counts()
# Out:
# category
# Accessories      16391
# Hardware         12079
# Smart tech        8512
# Service           5268
# PC                4433
# Tablet            3496
# Smartphone        2521
# Uncategorized     1904
# Digital            373
# MP3 player         343
# Name: count, dtype: int64

# %%
ol_pr.groupby('category')[['unit_price']].sum().sort_values(ascending=False, by='unit_price')
# Out:
#                unit_price
# category
# Hardware       1672948.77
# Accessories    1419184.89
# Smartphone     1330851.87
# Service         800353.12
# Smart tech      783286.32
# Tablet          687151.34
# PC              411463.79
# Uncategorized   296432.87
# Digital          39118.43
# MP3 player       29403.97

# %%
category_income = ol_pr.groupby('category')[['unit_price']].sum().sort_values(ascending=False, by='unit_price')

# %%
ol_pr
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119134    299556           0                 1  CRU0039-A       60.90
# 4      1119145    299561           0                 1    PEB0015      142.49
# ...        ...       ...         ...               ...        ...         ...
# 56709  1649474    525664           0                 1    TUC0207       16.52
# 56710  1649512    527070           0                 2    APP0698        9.99
# 56711  1649522    527074           0                 2    APP0698        9.99
# 56712  1649565    527096           0                 3    APP0698        9.99
# 56713  1649593    527112           0                 1    APP0698        9.99
#
# ...

# %%
# category of the most popular products

# %%
ol_pr.groupby(['sku', 'name', 'category'])[['product_quantity']].sum().sort_values(ascending=False, by='product_quantity').head(20)
# Out:
#                                                                           product_quantity
# sku       name                                               category
# APP1190   IPhone AppleCare Protection Plan                   Service                   965
# APP0698   Apple Lightning Cable Connector to USB 1m White... Accessories               838
# APP1922   AirPods Apple Bluetooth Headset for iPhone iPad... Accessories               563
# WDT0183   Red 4TB WD 35 "Mac PC hard drive and NAS           Hardware                  505
# APP0927   EarPods Apple Headphones with Remote and Mic (OEM) Accessories               493
# CRU0051   Crucial MX300 525GB SSD Disk                       Hardware                  359
# SAM0074   Samsung 850 EVO SSD Disk 500GB                     Hardware                  356
# NTE0013   AdaptaDrive NewerTech adapter 2.5 "to 3.5" SATA    Smart tech                292
# ...

# %%
ol_pr.groupby(['sku', 'name', 'category'])[['product_quantity']].sum().sort_values(ascending=False, by='product_quantity').head(20)
# Out:
#                                                                           product_quantity
# sku       name                                               category
# APP1190   IPhone AppleCare Protection Plan                   Service                   965
# APP0698   Apple Lightning Cable Connector to USB 1m White... Accessories               838
# APP1922   AirPods Apple Bluetooth Headset for iPhone iPad... Accessories               563
# WDT0183   Red 4TB WD 35 "Mac PC hard drive and NAS           Hardware                  505
# APP0927   EarPods Apple Headphones with Remote and Mic (OEM) Accessories               493
# CRU0051   Crucial MX300 525GB SSD Disk                       Hardware                  359
# SAM0074   Samsung 850 EVO SSD Disk 500GB                     Hardware                  356
# NTE0013   AdaptaDrive NewerTech adapter 2.5 "to 3.5" SATA    Smart tech                292
# ...

# %%
top_20_popular_items = ol_pr.groupby(['sku', 'name', 'category'])[['product_quantity']].sum().sort_values(ascending=False, by='product_quantity').head(20).reset_index()

# %%
top_20_popular_items['color'] = ''

# %%
top_20_popular_items
# Out:
#           sku                                               name     category  \
# 0     APP1190                   IPhone AppleCare Protection Plan      Service
# 1     APP0698  Apple Lightning Cable Connector to USB 1m Whit...  Accessories
# 2     APP1922  AirPods Apple Bluetooth Headset for iPhone iPa...  Accessories
# 3     WDT0183           Red 4TB WD 35 "Mac PC hard drive and NAS     Hardware
# 4     APP0927  EarPods Apple Headphones with Remote and Mic (...  Accessories
# 5     CRU0051                       Crucial MX300 525GB SSD Disk     Hardware
# 6     SAM0074                     Samsung 850 EVO SSD Disk 500GB     Hardware
# 7     NTE0013    AdaptaDrive NewerTech adapter 2.5 "to 3.5" SATA   Smart tech
# 8     APP2446                     Apple iPhone 6 32GB Space Gray   Smartphone
# 9     CRU0050                       Crucial MX300 275GB SSD Disk     Hardware
# 10    WDT0141           WD Red 3TB 35 "Mac PC hard drive and NAS     Hardware
# ...

# %%
top_20_popular_items.groupby('category')[['product_quantity']].sum().sort_values(ascending=False, by='product_quantity')
# Out:
#              product_quantity
# category
# Accessories              2853
# Hardware                 2400
# Service                   965
# Smartphone                499
# Smart tech                292
# Tablet                    214

# %%
# category of products with the highest income

# %%
ol_pr.groupby(['sku', 'name', 'category'])[['product_quantity', 'unit_price']].sum().sort_values(ascending=False, by='unit_price').head(20).reset_index()
# Out:
#         sku                                               name     category  \
# 0   LGE0044       LG 27UD88-W Monitor 27 "UHD 4K USB 3.0 USB-C  Accessories
# 1   APP2446                     Apple iPhone 6 32GB Space Gray   Smartphone
# 2   APP1922  AirPods Apple Bluetooth Headset for iPhone iPa...  Accessories
# 3   APP2477                     Apple iPhone 64GB Space Gray 8   Smartphone
# 4   APP1970                       Apple iPhone 32GB Space Gray   Smartphone
# 5   APP2072  Apple MacBook Air 13 "Core i5 18GHz | 8GB RAM ...           PC
# 6   APP2485                      Apple iPhone 8 Plus 64GB Gold   Smartphone
# 7   APP2483                Apple iPhone 8 Plus 64GB Space Gray   Smartphone
# 8   APP2479                           Apple iPhone 64GB Gold 8   Smartphone
# 9   APP1966                           Apple iPhone 32GB Silver   Smartphone
# 10  SAM0074                     Samsung 850 EVO SSD Disk 500GB     Hardware
# ...

# %%
top_20_most_income = ol_pr.groupby(['sku', 'name', 'category'])[['product_quantity', 'unit_price']].sum().sort_values(ascending=False, by='unit_price').head(20).reset_index()

# %%
top_20_most_income.groupby('category')[['unit_price']].sum().sort_values(ascending=False, by='unit_price')
# Out:
#              unit_price
# category
# Smartphone    664380.01
# Accessories   201955.07
# Hardware      131545.04
# PC             74816.30
# Service        47714.64
# Tablet         42138.25
# Smart tech     39534.45

# %%
top_20_most_income_category = top_20_most_income.groupby('category')[['unit_price']].sum().sort_values(ascending=False, by='unit_price')

# %%
ol_pr.groupby('category')[['unit_price']].sum().sort_values(ascending=False, by='unit_price')
# Out:
#                unit_price
# category
# Hardware       1672948.77
# Accessories    1419184.89
# Smartphone     1330851.87
# Service         800353.12
# Smart tech      783286.32
# Tablet          687151.34
# PC              411463.79
# Uncategorized   296432.87
# Digital          39118.43
# MP3 player       29403.97

# %%
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline
warnings.filterwarnings("ignore")

# %% [markdown]
# ### most popular items

# %%
# bar chart of most popular items

# %%
sns.catplot(kind='bar',
            data=top_20_popular_items,
            x='product_quantity',
            y='name',
            height=8,
            aspect=2,
            palette="mako");

# %% [markdown]
# ### most revenue items

# %%
# most revenue products

# %%
sns.catplot(kind='bar',
            data=top_20_most_income,
            x='unit_price',
            y='name',
            height=8,
            aspect=2,
            palette="mako");

# %% [markdown]
# ### quarterly data

# %%
# representing the quarterly income

# %%
# pie chart

# %%
import matplotlib.pyplot as plt
import seaborn

data = [41 , 14, 22, 48]
keys = ['Quarter 1', 'Quarter 2', 'Quarter 3', 'Quarter 4']

palette_color = seaborn.color_palette('crest')

plt.pie(data, labels=keys, colors=palette_color)

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn

data = [48 , 14, 22, 43]
keys = ['Quarter 1', 'Quarter 2', 'Quarter 3', 'Quarter 4']

palette_color = seaborn.color_palette('crest')

plt.pie(data, labels=keys, colors=palette_color)

plt.show()

# %%
# pie chart of order 'status'

# %%
import matplotlib.pyplot as plt
import seaborn

data = [61 , 21, 14, 4]
keys = ['Shopping basket', 'Completed', 'Placed', 'Cancelled']

# %%
def colors(states):
  color_list= []
  for state in states:
   if state == 'Completed':
    color_list.append('darkslategrey')
   elif state == 'Shopping basket':
    color_list.append('silver')
   elif state == 'Cancelled':
    color_list.append('lightgrey')
   else:
    color_list.append('gainsboro')
  return color_list

# %%
color_list = colors(keys)

# %%
plt.pie(data, labels=keys, colors=color_list)

plt.show()

# %% [markdown]
# ## categories color code

# %%
ol_pr
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119134    299556           0                 1  CRU0039-A       60.90
# 4      1119145    299561           0                 1    PEB0015      142.49
# ...        ...       ...         ...               ...        ...         ...
# 56709  1649474    525664           0                 1    TUC0207       16.52
# 56710  1649512    527070           0                 2    APP0698        9.99
# 56711  1649522    527074           0                 2    APP0698        9.99
# 56712  1649565    527096           0                 3    APP0698        9.99
# 56713  1649593    527112           0                 1    APP0698        9.99
#
# ...

# %%
ol_pr.groupby('category')[['unit_price']].sum().sort_values(ascending=False, by='unit_price').reset_index()
# Out:
#         category  unit_price
# 0       Hardware  1672948.77
# 1    Accessories  1419184.89
# 2     Smartphone  1330851.87
# 3        Service   800353.12
# 4     Smart tech   783286.32
# 5         Tablet   687151.34
# 6             PC   411463.79
# 7  Uncategorized   296432.87
# 8        Digital    39118.43
# 9     MP3 player    29403.97

# %%
ol_pr_category = ol_pr.groupby('category')[['unit_price']].sum().sort_values(ascending=False, by='unit_price').reset_index()

# %%
def colors(categories):
  if 'Hardware' in categories:
    return '#2c6e49'
  elif 'Accessories' in categories:
    return '#90a955'
  elif 'Smartphone' in categories:
    return '#20353E'
  elif 'Service' in categories:
    return '#598392'
  elif 'Smart tech' in categories:
    return '#7e6c6c'
  elif 'Tablet' in categories:
    return '#BD9B56'
  elif 'PC' in categories:
    return '#fca311'
  elif 'Digital' in categories:
    return '#D9DCDC'
  elif 'MP3 player' in categories:
    return '#D9DCDC'
  else:
    return '#D9DCDC'

# %%
ol_pr_category['color'] = ol_pr_category['category'].apply(colors)

# %%
sns.catplot(kind='bar',
            data=ol_pr_category,
            x='category',
            y='unit_price',
            height=8,
            aspect=2,
            palette=ol_pr_category['color'].tolist())

plt.ylabel('Income [€]', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14);

# %% [markdown]
# ## most popular items with color code

# %%
def colors(categories):
  if 'Hardware' in categories:
    return '#2c6e49'
  elif 'Accessories' in categories:
    return '#90a955'
  elif 'Smartphone' in categories:
    return '#20353E'
  elif 'Service' in categories:
    return '#598392'
  elif 'Smart tech' in categories:
    return '#7e6c6c'
  elif 'Tablet' in categories:
    return '#BD9B56'
  elif 'PC' in categories:
    return '#fca311'
  elif 'Digital' in categories:
    return '#D9DCDC'
  elif 'MP3 player' in categories:
    return '#D9DCDC'
  else:
    return '#D9DCDC'

# %%
top_20_popular_items
# Out:
#           sku                                               name     category  \
# 19    ZAG0032  Rugged Messenger Zagg iPad Keyboard Folio (201...       Tablet
# 8     APP2446                     Apple iPhone 6 32GB Space Gray   Smartphone
# 14    APP1970                       Apple iPhone 32GB Space Gray   Smartphone
# 7     NTE0013    AdaptaDrive NewerTech adapter 2.5 "to 3.5" SATA   Smart tech
# 0     APP1190                   IPhone AppleCare Protection Plan      Service
# 3     WDT0183           Red 4TB WD 35 "Mac PC hard drive and NAS     Hardware
# 5     CRU0051                       Crucial MX300 525GB SSD Disk     Hardware
# 6     SAM0074                     Samsung 850 EVO SSD Disk 500GB     Hardware
# 9     CRU0050                       Crucial MX300 275GB SSD Disk     Hardware
# 10    WDT0141           WD Red 3TB 35 "Mac PC hard drive and NAS     Hardware
# 15  CRU0026-2  Crucial memory Mac 16GB (2x8GB) SO-DIMM DDR3 1...     Hardware
# ...

# %%
top_20_popular_items.sort_values(by=['category','product_quantity'], ascending=False)
# Out:
#           sku                                               name     category  \
# 19    ZAG0032  Rugged Messenger Zagg iPad Keyboard Folio (201...       Tablet
# 8     APP2446                     Apple iPhone 6 32GB Space Gray   Smartphone
# 14    APP1970                       Apple iPhone 32GB Space Gray   Smartphone
# 7     NTE0013    AdaptaDrive NewerTech adapter 2.5 "to 3.5" SATA   Smart tech
# 0     APP1190                   IPhone AppleCare Protection Plan      Service
# 3     WDT0183           Red 4TB WD 35 "Mac PC hard drive and NAS     Hardware
# 5     CRU0051                       Crucial MX300 525GB SSD Disk     Hardware
# 6     SAM0074                     Samsung 850 EVO SSD Disk 500GB     Hardware
# 9     CRU0050                       Crucial MX300 275GB SSD Disk     Hardware
# 10    WDT0141           WD Red 3TB 35 "Mac PC hard drive and NAS     Hardware
# 15  CRU0026-2  Crucial memory Mac 16GB (2x8GB) SO-DIMM DDR3 1...     Hardware
# ...

# %%
top_20_popular_items = top_20_popular_items.sort_values(by=['category','product_quantity'], ascending=False)

# %%
top_20_popular_items
# Out:
#           sku                                               name     category  \
# 19    ZAG0032  Rugged Messenger Zagg iPad Keyboard Folio (201...       Tablet
# 8     APP2446                     Apple iPhone 6 32GB Space Gray   Smartphone
# 14    APP1970                       Apple iPhone 32GB Space Gray   Smartphone
# 7     NTE0013    AdaptaDrive NewerTech adapter 2.5 "to 3.5" SATA   Smart tech
# 0     APP1190                   IPhone AppleCare Protection Plan      Service
# 3     WDT0183           Red 4TB WD 35 "Mac PC hard drive and NAS     Hardware
# 5     CRU0051                       Crucial MX300 525GB SSD Disk     Hardware
# 6     SAM0074                     Samsung 850 EVO SSD Disk 500GB     Hardware
# 9     CRU0050                       Crucial MX300 275GB SSD Disk     Hardware
# 10    WDT0141           WD Red 3TB 35 "Mac PC hard drive and NAS     Hardware
# 15  CRU0026-2  Crucial memory Mac 16GB (2x8GB) SO-DIMM DDR3 1...     Hardware
# ...

# %%
top_20_popular_items['color'] = top_20_popular_items['category'].apply(colors)

# %%
sns.catplot(kind='bar',
            data=top_20_popular_items,
            x='product_quantity',
            y='name',
            height=8,
            aspect=2,
            palette=top_20_popular_items['color'].tolist())
plt.xlabel('Product Quantity', fontsize=16)
plt.ylabel('Name', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=10);

# %% [markdown]
# ## most revenue items with color code

# %%
top_20_most_income.sort_values(by=['category','unit_price'], ascending=False)
# Out:
#         sku                                               name     category  \
# 14  APP1978                   Apple iPad Wi-Fi 32GB Space Gray       Tablet
# 1   APP2446                     Apple iPhone 6 32GB Space Gray   Smartphone
# 3   APP2477                     Apple iPhone 64GB Space Gray 8   Smartphone
# 4   APP1970                       Apple iPhone 32GB Space Gray   Smartphone
# 6   APP2485                      Apple iPhone 8 Plus 64GB Gold   Smartphone
# 7   APP2483                Apple iPhone 8 Plus 64GB Space Gray   Smartphone
# 8   APP2479                           Apple iPhone 64GB Gold 8   Smartphone
# 9   APP1966                           Apple iPhone 32GB Silver   Smartphone
# 12  APP2478                         Apple iPhone 64GB Silver 8   Smartphone
# 13  APP1971                   Apple iPhone SE 128GB Space Gray   Smartphone
# 16  AP20264           Like new - Apple iPhone 7 Plus 128GB RED   Smartphone
# ...

# %%
top_20_most_income = top_20_most_income.sort_values(by=['category','unit_price'], ascending=False)

# %%
top_20_most_income
# Out:
#         sku                                               name     category  \
# 14  APP1978                   Apple iPad Wi-Fi 32GB Space Gray       Tablet
# 1   APP2446                     Apple iPhone 6 32GB Space Gray   Smartphone
# 3   APP2477                     Apple iPhone 64GB Space Gray 8   Smartphone
# 4   APP1970                       Apple iPhone 32GB Space Gray   Smartphone
# 6   APP2485                      Apple iPhone 8 Plus 64GB Gold   Smartphone
# 7   APP2483                Apple iPhone 8 Plus 64GB Space Gray   Smartphone
# 8   APP2479                           Apple iPhone 64GB Gold 8   Smartphone
# 9   APP1966                           Apple iPhone 32GB Silver   Smartphone
# 12  APP2478                         Apple iPhone 64GB Silver 8   Smartphone
# 13  APP1971                   Apple iPhone SE 128GB Space Gray   Smartphone
# 16  AP20264           Like new - Apple iPhone 7 Plus 128GB RED   Smartphone
# ...

# %%
top_20_most_income['color'] = top_20_most_income['category'].apply(colors)

# %%
sns.catplot(kind='bar',
            data=top_20_most_income,
            x='unit_price',
            y='name',
            height=8,
            aspect=2,
            palette=top_20_most_income['color'].tolist())
plt.xlabel('Income [€]', fontsize=16)
plt.ylabel('Name', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=10);

# %% [markdown]
# ## monthly income with color code

# %%
monthly_income
# Out:
#     year  month  total_paid
# 0   2017      1  1076463.39
# 1   2017      2   559303.39
# 2   2017      3    39107.50
# 3   2017      4   386674.71
# 4   2017      5   531927.11
# 5   2017      6   507378.37
# 6   2017      7   988687.54
# 7   2017      8   589515.69
# 8   2017      9   632319.52
# 9   2017     10   895959.38
# 10  2017     11  2527381.94
# 11  2017     12  1540190.10
# 12  2018      1  1394971.71
# 13  2018      2   825950.40
# 14  2018      3   327506.76

# %%
monthly_income['month_year'] = monthly_income['month'].astype(str) + '-' + monthly_income['year'].astype(str)

# %%
monthly_income
# Out:
#     year  month  total_paid month_year
# 0   2017      1  1076463.39     1-2017
# 1   2017      2   559303.39     2-2017
# 2   2017      3    39107.50     3-2017
# 3   2017      4   386674.71     4-2017
# 4   2017      5   531927.11     5-2017
# 5   2017      6   507378.37     6-2017
# 6   2017      7   988687.54     7-2017
# 7   2017      8   589515.69     8-2017
# 8   2017      9   632319.52     9-2017
# 9   2017     10   895959.38    10-2017
# 10  2017     11  2527381.94    11-2017
# 11  2017     12  1540190.10    12-2017
# 12  2018      1  1394971.71     1-2018
# 13  2018      2   825950.40     2-2018
# 14  2018      3   327506.76     3-2018

# %%
sns.relplot(kind="line",
            data=monthly_income,
            x='month_year',
            y='total_paid',
            height=8,
            aspect=2,
            color='seagreen',
            linewidth=6)
plt.xlabel('Time [months]', fontsize=16)
plt.ylabel('Income', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14);

# %% [markdown]
# ## numbers of discounts

# %%
ol_pr
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119134    299556           0                 1  CRU0039-A       60.90
# 4      1119145    299561           0                 1    PEB0015      142.49
# ...        ...       ...         ...               ...        ...         ...
# 56709  1649474    525664           0                 1    TUC0207       16.52
# 56710  1649512    527070           0                 2    APP0698        9.99
# 56711  1649522    527074           0                 2    APP0698        9.99
# 56712  1649565    527096           0                 3    APP0698        9.99
# 56713  1649593    527112           0                 1    APP0698        9.99
#
# ...

# %%
ol_pr['unit_price'].sum()
# Out:
# 7470195.37

# %%
ol_pr['discount_amount'] = ol_pr['price'] - ol_pr['unit_price']

# %%
ol_pr
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119134    299556           0                 1  CRU0039-A       60.90
# 4      1119145    299561           0                 1    PEB0015      142.49
# ...        ...       ...         ...               ...        ...         ...
# 56709  1649474    525664           0                 1    TUC0207       16.52
# 56710  1649512    527070           0                 2    APP0698        9.99
# 56711  1649522    527074           0                 2    APP0698        9.99
# 56712  1649565    527096           0                 3    APP0698        9.99
# 56713  1649593    527112           0                 1    APP0698        9.99
#
# ...

# %%
ol_pr.groupby(['sku', 'name'])[['product_quantity', 'unit_price']].sum().sort_values(ascending=False, by='unit_price').head(20)
# Out:
#                                                             product_quantity  \
# sku     name
# LGE0044 LG 27UD88-W Monitor 27 "UHD 4K USB 3.0 USB-C                     243
# APP2446 Apple iPhone 6 32GB Space Gray                                   271
# APP1922 AirPods Apple Bluetooth Headset for iPhone iPad...               563
# APP2477 Apple iPhone 64GB Space Gray 8                                   111
# APP1970 Apple iPhone 32GB Space Gray                                     228
# APP2072 Apple MacBook Air 13 "Core i5 18GHz | 8GB RAM |...                78
# APP2485 Apple iPhone 8 Plus 64GB Gold                                     83
# APP2483 Apple iPhone 8 Plus 64GB Space Gray                               69
# APP2479 Apple iPhone 64GB Gold 8                                          68
# APP1966 Apple iPhone 32GB Silver                                         141
# SAM0074 Samsung 850 EVO SSD Disk 500GB                                   356
# ...

# %%
ol_pr.groupby(['sku', 'name'])['unit_price'].sum().sort_values(ascending=False).head(20)
# Out:
# sku      name
# LGE0044  LG 27UD88-W Monitor 27 "UHD 4K USB 3.0 USB-C                                   116033.15
# APP2446  Apple iPhone 6 32GB Space Gray                                                 101083.49
# APP1922  AirPods Apple Bluetooth Headset for iPhone iPad iPod and Apple Watch            85921.92
# APP2477  Apple iPhone 64GB Space Gray 8                                                  82683.26
# APP1970  Apple iPhone 32GB Space Gray                                                    81356.18
# APP2072  Apple MacBook Air 13 "Core i5 18GHz | 8GB RAM | 128GB SSD                       74816.30
# APP2485  Apple iPhone 8 Plus 64GB Gold                                                   72779.87
# APP2483  Apple iPhone 8 Plus 64GB Space Gray                                             57012.00
# APP2479  Apple iPhone 64GB Gold 8                                                        52855.41
# ...

# %%
top_20_most_revenue_income = ol_pr.groupby(['sku', 'name'])[['product_quantity','unit_price','discount_amount']].sum().sort_values(ascending=False, by='unit_price').head(20)

# %%
top_20_most_revenue_income['unit_price'].sum()
# Out:
# 1202083.76

# %%
# number of products in general

# %%
ol_pr['sku'].count()
# Out:
# 55320

# %%
ol_pr['discount_amount'] = pd.to_numeric(ol_pr['discount_amount'], errors='coerce')

# %%
# how many products were discounted

# %%
ol_pr.loc[ol_pr['discount_amount'] > 0]['discount_amount'].count()
# Out:
# 51409

# %%
# % of income from discounted products

# %%
ol_pr.loc[ol_pr['discount_amount'] > 0]['unit_price'].sum()
# Out:
# 6932457.779999999

# %%
import matplotlib.pyplot as plt
import seaborn

data = [93, 7]
keys = ['Discounted', 'Non discounted']

palette_color = seaborn.color_palette('cubehelix')

plt.pie(data, labels=keys, colors=palette_color)
plt.show()

# %%
# 5 of discounted products during christmas sales

# %%
date_filtering_df.loc[date_filtering_df['created_date'].between('2017-12-10', '2018-01-01')]['total_paid'].sum()
# Out:
# 1326551.7999999998

# %%
date_filtering_df['discount_amount'] = ol_pr['price'] - ol_pr['unit_price']

# %%
date_filtering_df
# Out:
#        order_id        created_date  total_paid      state       id  id_order  \
# 0        241423 2017-11-06 13:10:02      136.15  Completed  1398738    241423
# 1        242832 2017-12-31 17:40:03       15.76  Completed  1529178    242832
# 2        243330 2017-02-16 10:59:38       84.98  Completed  1181923    243330
# 3        245275 2017-06-28 11:35:37      149.00  Completed  1276706    245275
# 4        245595 2017-01-21 12:52:47      112.97  Completed  1154394    245595
# ...         ...                 ...         ...        ...      ...       ...
# 56709    527042 2018-03-14 11:47:50       18.98  Completed  1649446    527042
# 56710    527070 2018-03-14 11:50:48       24.97  Completed  1649512    527070
# 56711    527074 2018-03-14 11:51:42       24.97  Completed  1649522    527074
# 56712    527096 2018-03-14 11:58:40       34.96  Completed  1649565    527096
# 56713    527112 2018-03-14 12:03:52       14.98  Completed  1649593    527112
#
# ...

# %%
date_filtering_df.loc[date_filtering_df['created_date'].between('2017-12-10', '2018-01-01')]['discount_amount'].sum()
# Out:
# 139403.45

# %%
date_filtering_df.loc[date_filtering_df['created_date'].between('2017-12-10', '2018-01-01')]['unit_price'].sum()
# Out:
# 830669.88

# %%
date_filtering_df.loc[date_filtering_df['created_date'].between('2017-12-10', '2018-01-01')]['total_paid'].sum()
# Out:
# 1326551.7999999998

# %%
christmas_time = date_filtering_df.loc[date_filtering_df['created_date'].between('2017-12-10', '2018-01-01')]

# %%
christmas_time
# Out:
#        order_id        created_date  total_paid      state       id  id_order  \
# 1        242832 2017-12-31 17:40:03       15.76  Completed  1529178    242832
# 46       257280 2017-12-20 14:49:52      260.00  Completed  1507643    257280
# 52       259283 2017-12-22 09:19:28       24.98  Completed  1510299    259283
# 74       267194 2017-12-19 21:22:34       75.98  Completed  1505973    267194
# 118      285582 2017-12-18 19:04:40       56.98  Completed  1503336    285582
# ...         ...                 ...         ...        ...      ...       ...
# 45119    478292 2017-12-31 23:38:02      487.96  Completed  1529504    478292
# 45120    478292 2017-12-31 23:38:02      487.96  Completed  1529532    478292
# 45121    478293 2017-12-31 22:18:32       28.23  Completed  1529501    478293
# 45122    478296 2017-12-31 22:41:57       21.98  Completed  1529509    478296
# 45123    478314 2017-12-31 23:55:02      358.38  Completed  1529549    478314
#
# ...

# %%
christmas_time.groupby('discount_amount')[['unit_price']].sum().sort_values(ascending=False, by='unit_price')
# Out:
#                  unit_price
# discount_amount
# 10.00              24815.00
# 3.00               19080.81
# 39.99              17817.31
# 20.00              15555.80
# 2.00               14624.48
# ...                     ...
# 4.09                   4.49
# 19.96                  3.99
# 17.50                  3.19
# 33.91                  2.99
# 22.43                  2.69
#
# [1238 rows x 1 columns]

# %% [markdown]
# ## discounted products during Christmas time

# %%
christmas_time['unit_price'].sum()
# Out:
# 830669.88

# %%
christmas_time['discount_amount'].count()
# Out:
# 5348

# %%
christmas_time.loc[christmas_time['discount_amount'] > 0]['discount_amount'].count()
# Out:
# 5164

# %%
# the amount that was discounted

# %%
christmas_time.loc[christmas_time['discount_amount'] > 0]['discount_amount'].sum()
# Out:
# 139689.82

# %%
christmas_time.loc[christmas_time['discount_amount'] > 0]
# Out:
#        order_id        created_date  total_paid      state       id  id_order  \
# 1        242832 2017-12-31 17:40:03       15.76  Completed  1529178    242832
# 46       257280 2017-12-20 14:49:52      260.00  Completed  1507643    257280
# 52       259283 2017-12-22 09:19:28       24.98  Completed  1510299    259283
# 74       267194 2017-12-19 21:22:34       75.98  Completed  1505973    267194
# 118      285582 2017-12-18 19:04:40       56.98  Completed  1503336    285582
# ...         ...                 ...         ...        ...      ...       ...
# 45119    478292 2017-12-31 23:38:02      487.96  Completed  1529504    478292
# 45120    478292 2017-12-31 23:38:02      487.96  Completed  1529532    478292
# 45121    478293 2017-12-31 22:18:32       28.23  Completed  1529501    478293
# 45122    478296 2017-12-31 22:41:57       21.98  Completed  1529509    478296
# 45123    478314 2017-12-31 23:55:02      358.38  Completed  1529549    478314
#
# ...

# %%
christmas_time_only_discounted = christmas_time.loc[christmas_time['discount_amount'] > 0]

# %%
# discounted products and their income

# %%
christmas_time_only_discounted['unit_price'].sum()
# Out:
# 790615.85

# %%
# the total income from the order

# %%
christmas_time_only_discounted['total_paid'].sum()
# Out:
# 1257322.95

# %% [markdown]
# ## discounted products during Black Friday

# %%
date_filtering_df.loc[date_filtering_df['created_date'].dt.strftime("%Y-%m-%d") == '2017-11-24']
# Out:
#        order_id        created_date  total_paid      state       id  id_order  \
# 9        246405 2017-11-24 10:01:27      407.96  Completed  1434161    246405
# 10       246405 2017-11-24 10:01:27      407.96  Completed  1434233    246405
# 11       246405 2017-11-24 10:01:27      407.96  Completed  1434356    246405
# 12       246405 2017-11-24 10:01:27      407.96  Completed  1434434    246405
# 18       251688 2017-11-24 23:57:07      505.76  Completed  1432401    251688
# ...         ...                 ...         ...        ...      ...       ...
# 35827    442226 2017-11-24 23:55:37     1569.47  Completed  1443972    442226
# 35828    442226 2017-11-24 23:55:37     1569.47  Completed  1443979    442226
# 35829    442226 2017-11-24 23:55:37     1569.47  Completed  1443984    442226
# 35830    442229 2017-11-24 23:57:17       72.98  Completed  1443966    442229
# 35833    442234 2017-11-24 23:58:25       82.39  Completed  1443976    442234
#
# ...

# %%
black_friday_time = date_filtering_df.loc[date_filtering_df['created_date'].dt.strftime("%Y-%m-%d") == '2017-11-24']

# %%
# number of products

# %%
black_friday_time['unit_price'].count()
# Out:
# 2003

# %%
black_friday_time.loc[black_friday_time['discount_amount'] > 0]
# Out:
#        order_id        created_date  total_paid      state       id  id_order  \
# 9        246405 2017-11-24 10:01:27      407.96  Completed  1434161    246405
# 10       246405 2017-11-24 10:01:27      407.96  Completed  1434233    246405
# 11       246405 2017-11-24 10:01:27      407.96  Completed  1434356    246405
# 12       246405 2017-11-24 10:01:27      407.96  Completed  1434434    246405
# 18       251688 2017-11-24 23:57:07      505.76  Completed  1432401    251688
# ...         ...                 ...         ...        ...      ...       ...
# 35827    442226 2017-11-24 23:55:37     1569.47  Completed  1443972    442226
# 35828    442226 2017-11-24 23:55:37     1569.47  Completed  1443979    442226
# 35829    442226 2017-11-24 23:55:37     1569.47  Completed  1443984    442226
# 35830    442229 2017-11-24 23:57:17       72.98  Completed  1443966    442229
# 35833    442234 2017-11-24 23:58:25       82.39  Completed  1443976    442234
#
# ...

# %%
black_friday_discounted = black_friday_time.loc[black_friday_time['discount_amount'] > 0]

# %%
# income from discounted products

# %%
black_friday_discounted['unit_price'].sum()
# Out:
# 348403.28

# %%
# number of discounted products

# %%
black_friday_discounted['unit_price'].count()
# Out:
# 1948
